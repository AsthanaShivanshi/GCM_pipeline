# %%
import xarray as xr

# %%
pr= xr.open_dataset("/work/FAC/FGSE/IDYST/tbeucler/downscaling/sasthana/Downscaling/GCM_pipeline/EUROCORDEX_11/pr/pr_day_EUR-11_CLMcom-CCLM4-8-17_ICHEC-EC-EARTH_r12i1p1_rcp85_1971-2099.nc")["pr"]

# %%
pr.dims
# Out:
# ('time', 'rlat', 'rlon')

# %%
pr.coords
# Out:
# Coordinates:
#   * rlon     (rlon) float64 3kB -28.38 -28.27 -28.16 ... 17.94 18.05 18.16
#   * rlat     (rlat) float64 3kB -23.38 -23.27 -23.16 ... 21.62 21.73 21.84
#   * time     (time) datetime64[ns] 377kB 1971-01-01T12:00:00 ... 2099-12-31T1...
#     lat      (rlat, rlon) float64 1MB ...
#     lon      (rlat, rlon) float64 1MB ...

# %%
pr_mask=xr.open_dataset("/work/FAC/FGSE/IDYST/tbeucler/downscaling/sasthana/Downscaling/GCM_pipeline/EUROCORDEX_11/precip_mask_11km.nc")["mask"]

# %%
pr_mask.dims
# Out:
# ('N', 'E')

# %%
pr_mask.coords
# Out:
# Coordinates:
#     lon      (N, E) float32 3kB ...
#     lat      (N, E) float32 3kB ...
#   * E        (E) float64 264B 2.48e+06 2.49e+06 2.502e+06 ... 2.82e+06 2.832e+06
#   * N        (N) float64 168B 1.07e+06 1.08e+06 1.092e+06 ... 1.278e+06 1.29e+06
